# %%
html_docs1="""
<HTML>
<HEAD>
<TITLE>United States Patent: 7811611</TITLE></HEAD>
<!-BUF1=7811611
<BASE target="_top">
</HEAD>
<BODY bgcolor="#FFFFFF">
<TABLE>

       <FONT size="+1">Herbal contraceptive formulation
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> Disclosed herein are non-synthetic herbal based anti-fertility
     compositions having high spermicidal activity for intravaginal
     administration comprising hydroalcoholic extract of Annona squamosa and
     pharmaceutically acceptable excipients, in suitably formulated dosage
     forms for intravaginal administration and a method of contraception in a
     female subject to prevent pregnancy.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Singh; Kamalinder Kaur</B> (Mumbai, Maharashtra, <B>IN</B>)<B>, Tatke; Pratima Arun</B> (Mumbai, Maharashtra, <B>IN</B>)<B>, Dhuru; Shruti</B> (Mahim, Mumbai, Maharashtra, <B>IN</B>) </TD> </TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>36587116</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>11/884,677</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>January 19, 2006</b></TD></TR>
       
     </TABLE>


</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs1, 'html.parser')


print(soup.body.table.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())

data=[]

for tr in soup.find_all('b'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Herbal contraceptive formulation
#
#  Disclosed herein are non-synthetic herbal based anti-fertility
#      compositions having high spermicidal activity for intravaginal
#      administration comprising hydroalcoholic extract of Annona squamosa and
#      pharmaceutically acceptable excipients, in suitably formulated dosage
#      forms for intravaginal administration and a method of contraception in a
#      female subject to prevent pregnancy.
#
#  Inventors:
# Singh; Kamalinder Kaur (Mumbai, Maharashtra, IN), Tatke; Pratima Arun (Mumbai, Maharashtra, IN), Dhuru; Shruti (Mahim, Mumbai, Maharashtra, IN)
# [('January 19, 2006', 'January', '19')]

# %%
html_docs2="""
<HTML>

<BODY bgcolor="#FFFFFF">

<TABLE width="100%">

       <FONT size="+1">Method for preparation of herbal beverage
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> A process for the preparation (decoction) of an herbal beverage from
     China Root (Smilax domingensis Willd), Bejuco indio (Gouania polygama)
     and Pimento leaves (Pimenta dioica Merr) and a modulation effective
     amount of Ginger root (Zingiber offiicinale); and the product prepared in
     accordance with this process.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Otero; Douglas</B> (Miami, FL) </TD> </TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>44513538
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>12/803,828</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>July 7, 2010</b></TD></TR>
     </TABLE>
    
</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs2, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Method for preparation of herbal beverage
#
#  A process for the preparation (decoction) of an herbal beverage from
#      China Root (Smilax domingensis Willd), Bejuco indio (Gouania polygama)
#      and Pimento leaves (Pimenta dioica Merr) and a modulation effective
#      amount of Ginger root (Zingiber offiicinale); and the product prepared in
#      accordance with this process.
#
#  Inventors:
# Otero; Douglas (Miami, FL)
# [('July 7, 2010', 'July', '7')]

# %%
html_docs3="""
<HTML>

<BODY bgcolor="#FFFFFF">


<TABLE width="100%">
       <FONT size="+1">Antiperspirant/deodorant composition
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> A composition comprising at least one plant derived oil having a melting
     point of about -15 to about 38.degree. C. in an amount of about 5% or
     less by weight; and at least one active chosen from antiperspirant
     actives and deodorant actives in an amount of about 0.5 to about 16% by
     weight of the composition on an active weight basis. The composition can
     be used as an antiperspirant and/or deodorant when applied to an axillary
     area of a person.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Popoff; Christine M.</B> (Morganville, NJ)<B>, Henao; Diana</B> (Dover, NJ) </TD> </TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Colgate-Palmolive Company</B>
 (New York, 
NY)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>39592125
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>11/670,472</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>February 2, 2007</b></TD></TR>
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs3, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Antiperspirant/deodorant composition
#
#  A composition comprising at least one plant derived oil having a melting
#      point of about -15 to about 38.degree. C. in an amount of about 5% or
#      less by weight; and at least one active chosen from antiperspirant
#      actives and deodorant actives in an amount of about 0.5 to about 16% by
#      weight of the composition on an active weight basis. The composition can
#      be used as an antiperspirant and/or deodorant when applied to an axillary
#      area of a person.
#
#  Inventors:
# Popoff; Christine M. (Morganville, NJ), Henao; Diana (Dover, NJ)
# [('February 2, 2007', 'February', '2')]

# %%
html_docs4="""
<HTML>

<BODY bgcolor="#FFFFFF">

<TABLE width="100%">

       <FONT size="+1">Use of guanidine compounds as physiological strengthening agents in the
     form of nutritional supplements, animal feed additives, in cosmetic
     preparations and as plant stimulants
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> Physiological strengthening agents in the form of nutritional
     supplements, feed additives or in cosmetic preparations in the
     non-medicinal field of application, as well as plant stimulating agents
     is the use of guanidine compounds of the general formula (I)
     ##STR00001##  or their salts, especially creatinol, creatinol-O-phosphate
     or one of their salts with aspartic acid, ascorbic acid, succinic acid,
     fumaric acid, acetic acid or phosphoric acid. R.sup.1 and R.sup.2 can be
     organic or inorganic compounds, such as, phosphate, sulfate, acetyl,
     formyl, methyl, ethyl or propyl. The compounds are as nutritional
     supplements for, e.g., human being in the fields of education, sports,
     reconvalescence or geriatrics They can also be used as animal feed
     additives.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Gastner; Thomas</B> (Trostberg, <B>DE</B>)<B>, Krimmer; Hans-Peter</B> (Kirchweidach, <B>DE</B>)<B>, Guthner; Thomas</B> (Trostberg, <B>DE</B>)<B>, Sturm; Werner</B> (Tacherting, <B>DE</B>) </TD> </TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Alzchem Trostberg GmbH</B>
 (Trostberg, 
<B>DE</B>)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>34877211
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>10/990,346</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>November 16, 2004</b></TD></TR>
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs4, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Use of guanidine compounds as physiological strengthening agents in the
#      form of nutritional supplements, animal feed additives, in cosmetic
#      preparations and as plant stimulants
#
#  Physiological strengthening agents in the form of nutritional
#      supplements, feed additives or in cosmetic preparations in the
#      non-medicinal field of application, as well as plant stimulating agents
#      is the use of guanidine compounds of the general formula (I)
#      ##STR00001##  or their salts, especially creatinol, creatinol-O-phosphate
#      or one of their salts with aspartic acid, ascorbic acid, succinic acid,
#      fumaric acid, acetic acid or phosphoric acid. R.sup.1 and R.sup.2 can be
#      organic or inorganic compounds, such as, phosphate, sulfate, acetyl,
#      formyl, methyl, ethyl or propyl. The compounds are as nutritional
#      supplements for, e.g., human being in the fields of education, sports,
# ...

# %%
html_docs5="""
<HTML>

<BODY bgcolor="#FFFFFF">

<TABLE width="100%">

       <FONT size="+1">Nutraceutical for the prevention and treatment of cancers and diseases
     affecting the liver
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> A composition comprising vegetable/herbal based dietary ingredients, or
     extracts, which contains vitamins and nutrients that provide a novel
     nontoxic treatment for liver cancers, hepatitis, and liver cirrhosis. The
     composition can be taken as a daily dietary supplement to enhance normal
     physiological functions of the body. The said composition, or extracts
     thereof, are useful and effective in the treatment and prevention of
     liver and possibly other cancers. The compositions are also useful for
     administration to patients with pre-existing hepatitis and/or liver
     cirrhosis. The compositions or extracts thereof may be useful for
     treating other cancers and other disorders, diseases, or conditions.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Bui; Can V.</B> (Harvey, LA)<B>, Bui, legal representative; Cuong Q.</B> (Harvey, LA) </TD> </TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Canthao Corporation</B>
 (DeWitt, 
NY)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>33539077
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>13/195,359</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>August 1, 2011</b></TD></TR>
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs5, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Nutraceutical for the prevention and treatment of cancers and diseases
#      affecting the liver
#
#  A composition comprising vegetable/herbal based dietary ingredients, or
#      extracts, which contains vitamins and nutrients that provide a novel
#      nontoxic treatment for liver cancers, hepatitis, and liver cirrhosis. The
#      composition can be taken as a daily dietary supplement to enhance normal
#      physiological functions of the body. The said composition, or extracts
#      thereof, are useful and effective in the treatment and prevention of
#      liver and possibly other cancers. The compositions are also useful for
#      administration to patients with pre-existing hepatitis and/or liver
#      cirrhosis. The compositions or extracts thereof may be useful for
#      treating other cancers and other disorders, diseases, or conditions.
#
#  Inventors:
# Bui; Can V. (Harvey, LA), Bui, legal representative; Cuong Q. (Harvey, LA)
# ...

# %%
html_docs6="""
<HTML>
<BODY bgcolor="#FFFFFF">

<TABLE width="100%">

       <FONT size="+1">Use of docosahexanoic acid as active substance for the treatment of
     lipodystrophy
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> Use of an extract of animal, plant or microorganism-produced origin
     comprising docosahexaenoic acid as active substance for the manufacture
     of a medicament for the treatment of lipodystrophy in a mammal. The
     medicament is administered to a patient who is concomitantly receiving a
     highly active anti-retroviral therapy (HAART). The treatment is effective
     and overcomes the disadvantages of current lipodystrophy treatments in
     HIV-infected patients.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Domingo Pedral; Juan Carlos</B> (Barcelona, <B>ES</B>)<B>, Domingo Pedral; Pere</B> (Barcelona, <B>ES</B>) </TD> </TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Proyecto Empresarial Brudy, S.L.</B>
 (Barcelona, 
<B>ES</B>)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>32405973
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>10/535,220</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>December 1, 2003</b></TD></TR>
      
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs6, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Use of docosahexanoic acid as active substance for the treatment of
#      lipodystrophy
#
#  Use of an extract of animal, plant or microorganism-produced origin
#      comprising docosahexaenoic acid as active substance for the manufacture
#      of a medicament for the treatment of lipodystrophy in a mammal. The
#      medicament is administered to a patient who is concomitantly receiving a
#      highly active anti-retroviral therapy (HAART). The treatment is effective
#      and overcomes the disadvantages of current lipodystrophy treatments in
#      HIV-infected patients.
#
#  Inventors:
# Domingo Pedral; Juan Carlos (Barcelona, ES), Domingo Pedral; Pere (Barcelona, ES)
# [('December 1, 2003', 'December', '1')]

# %%
html_docs7="""
<HTML>
<BODY bgcolor="#FFFFFF">

<TABLE width="100%">

       <FONT size="+1">Natural hair care composition, methods for obtaining the same and use
     thereof
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> Disclosed is a natural hair care composition comprising extract of
     flowers of plant Butea frondosa and/or stem bark of plant Butea
     parviflora, and/or the exudates of stem and root of plant Butea superba,
     and a cosmetically acceptable carrier. Also disclosed are methods for
     obtaining the plant extract and use thereof in regulation of hair growth
     and prevention of hair loss in all kinds of hair disorders.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Mitra; Shankar Kumar</B> (Bagalore, <B>IN</B>)<B>, Saxena; Ekta</B> (Bagalore, <B>IN</B>)<B>, Babu; Uddagiri Venkanna</B> (Bagalore, <B>IN</B>)<B>, Ranganna; Marikunte Venkata</B> (Bagalore, <B>IN</B>) </TD> </TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Himalaya Global Holdings, Ltd.</B>
 (Grand Cayman, 
<B>KY</B>)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>35757616
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>12/781,073</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>May 17, 2010</b></TD></TR>
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs7, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Natural hair care composition, methods for obtaining the same and use
#      thereof
#
#  Disclosed is a natural hair care composition comprising extract of
#      flowers of plant Butea frondosa and/or stem bark of plant Butea
#      parviflora, and/or the exudates of stem and root of plant Butea superba,
#      and a cosmetically acceptable carrier. Also disclosed are methods for
#      obtaining the plant extract and use thereof in regulation of hair growth
#      and prevention of hair loss in all kinds of hair disorders.
#
#  Inventors:
# Mitra; Shankar Kumar (Bagalore, IN), Saxena; Ekta (Bagalore, IN), Babu; Uddagiri Venkanna (Bagalore, IN), Ranganna; Marikunte Venkata (Bagalore, IN)
# [('May 17, 2010', 'May', '17')]

# %%
html_docs8="""
<HTML>
<BODY bgcolor="#FFFFFF">


<TABLE width="100%">

       <FONT size="+1">Lipid preparation for enhancing mineral absorption
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> Disclosed is a dietary ingredient comprising at least one edible lipid
     which does not inhibit mineral absorption, enhances mineral absorption
     and intake, particularly a chemically or enzymatically synthesized
     synthetic oil, particularly glyceride-based lipid with high levels of
     mono- or polyunsaturated fatty acids at positions sn-1 and sn-3 of the
     glycerol backbone, vegetable- and plant-derived oil, such as flax and
     canola oils, short and medium chains lipid, preferably MCT and an oil
     mimicking the triglyceride composition of human mother's milk fat and its
     various uses. The dietary ingredient is particularly intended for use in
     enhancing calcium absorption and in the prevention and/or treatment of
     disorders associated with depletion of bone calcium and bone density,
     prevention and treatment of osteoporosis, for the enhancement of bone
     formation and bone mass maximization and for the enhancement of bone
     formation in infants and young children.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Shulman; Avidor</B> (Kiryat Tivon, <B>IL</B>)<B>, Dror; Gai Ben</B> (Moshav Ofer, <B>IL</B>)<B>, Pelled; Dori</B> (Hod HaSharon, <B>IL</B>) </TD> </TR>
<TR><TH scope="row" valign="top" align="left" width="10%">Applicant: </TH><TD align="left" width="90%"> <TABLE> <TR> <TH scope="column" align="center">Name</TH> <TH scope="column" align="center">City</TH> <TH scope="column" align="center">State</TH> <TH
scope="column" align="center">Country</TH> <TH scope="column" align="center">Type</TH> </TR> <TR> <TD> <b><BR>Shulman; Avidor
<BR>Dror; Gai Ben
<BR>Pelled; Dori</b> </TD><TD> <BR>Kiryat Tivon
<BR>Moshav Ofer
<BR>Hod HaSharon </TD><TD align="center"> <BR>N/A
<BR>N/A
<BR>N/A </TD><TD align="center"> <BR>IL
<BR>IL
<BR>IL </TD> </TD><TD align="left"> </TD> </TR> </TABLE>
<!-- AANM>
~AANM Shulman; Avidor
~AACI Kiryat Tivon
~AAST N/A
~AACO IL
~AANM Dror; Gai Ben
~AACI Moshav Ofer
~AAST N/A
~AACO IL
~AANM Pelled; Dori
~AACI Hod HaSharon
~AAST N/A
~AACO IL
</AANM -->
</TD></TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Enzymotec Ltd.</B>
 (Migdal Haemeq, 
<B>IL</B>)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>34044225
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>10/576,239</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>October 21, 2004</b></TD></TR>
       
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs8, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Lipid preparation for enhancing mineral absorption
#
#  Disclosed is a dietary ingredient comprising at least one edible lipid
#      which does not inhibit mineral absorption, enhances mineral absorption
#      and intake, particularly a chemically or enzymatically synthesized
#      synthetic oil, particularly glyceride-based lipid with high levels of
#      mono- or polyunsaturated fatty acids at positions sn-1 and sn-3 of the
#      glycerol backbone, vegetable- and plant-derived oil, such as flax and
#      canola oils, short and medium chains lipid, preferably MCT and an oil
#      mimicking the triglyceride composition of human mother's milk fat and its
#      various uses. The dietary ingredient is particularly intended for use in
#      enhancing calcium absorption and in the prevention and/or treatment of
#      disorders associated with depletion of bone calcium and bone density,
#      prevention and treatment of osteoporosis, for the enhancement of bone
# ...

# %%
html_docs9="""
<HTML>
<BODY bgcolor="#FFFFFF">

<TABLE width="100%">

       <FONT size="+1">Method for producing a carnosic acid-rich plant extract
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> A carnosic acid-rich plant extract can be produced by extracting a dried
     and comminuted plant material containing carnosic acid with supercritical
     CO.sub.2 at a pressure of at least 200 bar and at a temperature of at
     most 100.degree. C. In a first step, supercritical CO.sub.2 in a quantity
     of 10 to 50 kg of CO.sub.2 per kg of plant material is passed through the
     plant material to obtain a first CO.sub.2 extract. In a second step,
     additional supercritical CO.sub.2 is passed through the plant material to
     obtain a second CO.sub.2 extract, and a carnosic acid-rich plant extract
     is separated from the second CO.sub.2 extract by lowering the pressure.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Wiesmueller; Johann</B> (Garching, <B>DE</B>)<B>, Michlbauer; Franz</B> (Kirchweidach, <B>DE</B>)<B>, Kahleyss; Ralf</B> (St. Georgen, <B>DE</B>)<B>, Hausner; Helmut</B> (Trostberg, <B>DE</B>) </TD> </TR>
<TR><TH scope="row" valign="top" align="left" width="10%">Applicant: </TH><TD align="left" width="90%"> <TABLE> <TR> <TH scope="column" align="center">Name</TH> <TH scope="column" align="center">City</TH> <TH scope="column" align="center">State</TH> <TH
scope="column" align="center">Country</TH> <TH scope="column" align="center">Type</TH> </TR> <TR> <TD> <b><BR>Wiesmueller; Johann
<BR>Michlbauer; Franz
<BR>Kahleyss; Ralf
<BR>Hausner; Helmut</b> </TD><TD> <BR>Garching
<BR>Kirchweidach
<BR>St. Georgen
<BR>Trostberg </TD><TD align="center"> <BR>N/A
<BR>N/A
<BR>N/A
<BR>N/A </TD><TD align="center"> <BR>DE
<BR>DE
<BR>DE
<BR>DE </TD> </TD><TD align="left"> </TD> </TR> </TABLE>
<!-- AANM>
~AANM Wiesmueller; Johann
~AACI Garching
~AAST N/A
~AACO DE
~AANM Michlbauer; Franz
~AACI Kirchweidach
~AAST N/A
~AACO DE
~AANM Kahleyss; Ralf
~AACI St. Georgen
~AAST N/A
~AACO DE
~AANM Hausner; Helmut
~AACI Trostberg
~AAST N/A
~AACO DE
</AANM -->
</TD></TR>
<TR> <TH scope="row" valign="top" align="left" width="10%">Assignee:</TH>
<TD align="left" width="90%">

<B>Evonik Degussa GmbH</B>
 (Essen, 
<B>DE</B>)
<BR>

</TD>
</TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>43531869
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>13/503,653</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>October 12, 2010</b></TD></TR>
       
     </TABLE>
</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs9, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Method for producing a carnosic acid-rich plant extract
#
#  A carnosic acid-rich plant extract can be produced by extracting a dried
#      and comminuted plant material containing carnosic acid with supercritical
#      CO.sub.2 at a pressure of at least 200 bar and at a temperature of at
#      most 100.degree. C. In a first step, supercritical CO.sub.2 in a quantity
#      of 10 to 50 kg of CO.sub.2 per kg of plant material is passed through the
#      plant material to obtain a first CO.sub.2 extract. In a second step,
#      additional supercritical CO.sub.2 is passed through the plant material to
#      obtain a second CO.sub.2 extract, and a carnosic acid-rich plant extract
#      is separated from the second CO.sub.2 extract by lowering the pressure.
#
#  Inventors:
# Wiesmueller; Johann (Garching, DE), Michlbauer; Franz (Kirchweidach, DE), Kahleyss; Ralf (St. Georgen, DE), Hausner; Helmut (Trostberg, DE)
# [('October 12, 2010', 'October', '12')]

# %%
html_docs10="""
<HTML>

<BODY bgcolor="#FFFFFF">


<TABLE width="100%">

       <FONT size="+1">Natural soap using herbal medicine mature decoction, and method of
     preparing the same
</FONT><BR>
       <BR><CENTER><b>Abstract</b></CENTER>
       <p> A natural soap is made using a herbal medicine decoction. The natural
     soap includes herbs including lotus roots, lotus leaves, red ginseng,
     Hippophae rhamnoides leaves and trunk, persimmon leaves, thuja
     orientalis, ginger, rosemary, black beans, black sesame, aloe, mulberry
     leaves, Orostachys japonicus, Angelica gigas, green tea, pine needles,
     mint, pleuropterus multiflorus, blueberry, and Acorus gramineus. A
     ripening device ripens the herbs in temperatures of 65 to 95.degree. C.
     for 3 to 15 days, distilled water or soft water is poured onto the herbs,
     and the herbs mixed with the water are decocted by a decoction maker.
</p>
       <HR>
<TABLE width="100%"> <TR> <TH scope="row" valign="top" align="left" width="10%">Inventors:</TH> <TD align="left" width="90%">
 <B>Ko; Eun Joo</B> (Seoul, <B>KR</B>) </TD> </TR>
<TR><TH scope="row" valign="top" align="left" width="10%">Applicant: </TH><TD align="left" width="90%"> <TABLE> <TR> <TH scope="column" align="center">Name</TH> <TH scope="column" align="center">City</TH> <TH scope="column" align="center">State</TH> <TH
scope="column" align="center">Country</TH> <TH scope="column" align="center">Type</TH> </TR> <TR> <TD> <b><BR>Ko; Eun Joo</b> </TD><TD> <BR>Seoul </TD><TD align="center"> <BR>N/A </TD><TD align="center"> <BR>KR </TD> </TD><TD align="left"> </TD> </TR>
</TABLE>
<!-- AANM>
~AANM Ko; Eun Joo
~AACI Seoul
~AAST N/A
~AACO KR
</AANM -->
</TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Family ID:
       </TD><TD align="left" width="90%">
       <b>46142501
</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%" nowrap>Appl. No.:
       </TH><TD align="left" width="90%">
       <b>13/735,397</b></TD></TR>
       <TR><TH scope="row" valign="top" align="left" width="10%">Filed:
       </TH><TD align="left" width="90%">
       <b>January 7, 2013</b></TD></TR>
     </TABLE>

</BODY>
</HTML>"""

# %%
import re
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_docs10, 'html.parser')


print(soup.body.font.get_text())
print(soup.body.table.p.get_text())
print(soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        print(matches)
# Out:
# Natural soap using herbal medicine mature decoction, and method of
#      preparing the same
#
#  A natural soap is made using a herbal medicine decoction. The natural
#      soap includes herbs including lotus roots, lotus leaves, red ginseng,
#      Hippophae rhamnoides leaves and trunk, persimmon leaves, thuja
#      orientalis, ginger, rosemary, black beans, black sesame, aloe, mulberry
#      leaves, Orostachys japonicus, Angelica gigas, green tea, pine needles,
#      mint, pleuropterus multiflorus, blueberry, and Acorus gramineus. A
#      ripening device ripens the herbs in temperatures of 65 to 95.degree. C.
#      for 3 to 15 days, distilled water or soft water is poured onto the herbs,
#      and the herbs mixed with the water are decocted by a decoction maker.
#
#  Inventors:
# Ko; Eun Joo (Seoul, KR)
# [('January 7, 2013', 'January', '7')]

# %%
import xlwt
from xlwt import Workbook
import re
from bs4 import BeautifulSoup

wb=Workbook()


sheet1=wb.add_sheet('Sheet 1',cell_overwrite_ok=True)

sheet1.write(0,1,'Name of the patent')
sheet1.write(0,2,'Abstract of the patent')
sheet1.write(0,3,'Assignee of the patent')
sheet1.write(0,4,'Filing Date of the patent')


soup = BeautifulSoup(html_docs1, 'html.parser')
sheet1.write(1,1,soup.body.table.font.get_text())
sheet1.write(1,2,soup.body.table.p.get_text())
sheet1.write(1,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(1,4,val)

soup = BeautifulSoup(html_docs2, 'html.parser')
sheet1.write(2,1,soup.body.table.font.get_text())
sheet1.write(2,2,soup.body.table.p.get_text())
sheet1.write(2,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(2,4,val)
            
soup = BeautifulSoup(html_docs3, 'html.parser')
sheet1.write(3,1,soup.body.table.font.get_text())
sheet1.write(3,2,soup.body.table.p.get_text())
sheet1.write(3,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(3,4,val)

            
soup = BeautifulSoup(html_docs4, 'html.parser')
sheet1.write(4,1,soup.body.table.font.get_text())
sheet1.write(4,2,soup.body.table.p.get_text())
sheet1.write(4,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(4,4,val)
            

soup = BeautifulSoup(html_docs5, 'html.parser')
sheet1.write(5,1,soup.body.table.font.get_text())
sheet1.write(5,2,soup.body.table.p.get_text())
sheet1.write(5,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(5,4,val)   
            
soup = BeautifulSoup(html_docs6, 'html.parser')
sheet1.write(6,1,soup.body.table.font.get_text())
sheet1.write(6,2,soup.body.table.p.get_text())
sheet1.write(6,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(6,4,val)  
            
            
soup = BeautifulSoup(html_docs7, 'html.parser')
sheet1.write(7,1,soup.body.table.font.get_text())
sheet1.write(7,2,soup.body.table.p.get_text())
sheet1.write(7,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(7,4,val)  
            
soup = BeautifulSoup(html_docs8, 'html.parser')
sheet1.write(8,1,soup.body.table.font.get_text())
sheet1.write(8,2,soup.body.table.p.get_text())
sheet1.write(8,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(8,4,val)  
            
soup = BeautifulSoup(html_docs9, 'html.parser')
sheet1.write(9,1,soup.body.table.font.get_text())
sheet1.write(9,2,soup.body.table.p.get_text())
sheet1.write(9,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(9,4,val)   
            
soup = BeautifulSoup(html_docs10, 'html.parser')
sheet1.write(10,1,soup.body.table.font.get_text())
sheet1.write(10,2,soup.body.table.p.get_text())
sheet1.write(10,3,soup.body.table.table.tr.get_text())


for tr in soup.find_all('tr'):
    matches = re.findall('((January|Jan|February|Feb|March|Mar|April|Apr|May|May|June|Jun|July|Jul|August|Aug|September|Sep|October|Oct|November|Nov|December|Dec)[ ](\d{1}|\d{2})[,][ ]\d{2,4})', tr.get_text())
    if matches!=[]:
        val=str(matches)
        sheet1.write(10,4,val)
            
wb.save('xlwt PatentsDet.xls')
# Out:
# [('January 19, 2006', 'January', '19')]
